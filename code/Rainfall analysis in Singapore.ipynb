# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Datasets Used in the Analysis
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-total-2023.csv`](./data/rainfall-monthly-total-2023.csv): This is the total monthly rainfall recorded in mm(millimetres) per month from January 1982 to April 2023.
#
# * [`rainfall-monthly-number-of-rain-days-2023.csv`](./data/rainfall-monthly-number-of-rain-days-2023.csv): This is the number of rain days in a month recorded per month from January 1982 to April 2023.

# %% [markdown]
# **Datasets used in the analysis:**
#
# * [`rainfall-monthly-total-2023.csv`](./data/rainfall-monthly-total-2023.csv): This is the total monthly rainfall recorded in mm(millimetres) per month from January 1982 to April 2023.
#
# * [`rainfall-monthly-number-of-rain-days-2023.csv`](./data/rainfall-monthly-number-of-rain-days-2023.csv): This is the number of rain days in a month recorded per month from January 1982 to April 2023.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Climate change is a global issue that has led to increasing extreme weather variations and heavy rainfall amounts (The National Aeronautics and Space Administration, n.d.), including more intense and frequent El Nino and La Nina events (Forgarty, 2023). Singapore, a low-lying island city-state already vulnerable to the impacts of climate change, is not spared from the intensification of these weather patterns. The existing urban infrastructure in Singapore, including drainage systems, canals, and reservoirs, that were designed based on historical weather patterns may not adequately address the heightened flood risks and surge from heavier rainfalls. Flash floods and prolonged inundation can cause severe disruptions, economic losses ("El Nino Costs Trillions", 2023), and endanger lives. Given these pressing concerns, there is an urgent need to review and update Singapore's urban development plans, especially flood adaptation measures.
# This project will analyse the rainfall trends from January 1982 to April 2023 in Singapore, and will seek to determine and justify the need for furthur studies and reviews on Singapore's urban development plans and flood adaptation measures to mitigate the effects of climate change.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# - Fogarty, D. (2023, May 19) Climate change has intensified El Nino and La Nina events, study finds. *The Straits Times*. https://www.straitstimes.com/world/climate-change-has-intensified-el-nino-and-la-nina-events-study-finds
#
# - The National Aeronautics and Space Administration (n.d.) *The Effects of Climate Change* Retrieved May 25, 2023, from https://climate.nasa.gov/effects/
#
# - El Nino costs trillions in lost economic growth, study shows. (2023, May 19). *The Straits Times*. https://www.straitstimes.com/world/el-ninos-cause-trillions-in-lost-economic-growth-study-shows

# %% [markdown]
# David Forgaty, in a The Straits Times article (Forgaty, 2023), cited a study led by researchers at Australia’s national science agency, the Commonwealth Scientific and Industrial Research Organisation (CSIRO). He warns of a more frequent and extreme El Nino and La Nina events that are expected from climate change. He added that these events have, in recent decades, triggered extreme heatwaves, droughts and wildfires and record floods, costing lives, destroying livelihoods and leading to billions of dollars in damage. He also quoted Dr Cai from the CSIRO on the urgency "for policymakers, resource managers and the public to start preperations for the social and economic risks" that are expected to come from such extreme weather variations.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_mean(list):
    return sum(list) / len(list)

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_std(list):
    mean = calculate_mean(list)
    z = []
    for x in list:
        z.append((x - mean) ** 2)
    variance = sum(z) / len(list)
    standard_deviation = variance ** 0.5
    return standard_deviation

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# read the rainfall-monthly-number-of-rain-days-2023 csv file, and make it into a dataframe number_of_rain_days_monthly
number_of_rain_days_monthly = pd.read_csv('../data/rainfall-monthly-number-of-rain-days-2023.csv')

# %%
# display the first 5 rows of dataframe
number_of_rain_days_monthly.head()
# Out:
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10

# %%
# check the data types of the dataframe
number_of_rain_days_monthly.dtypes
# Out:
# month               object
# no_of_rainy_days     int64
# dtype: object

# %%
# check for any null values
print(number_of_rain_days_monthly.isnull().sum())
print(number_of_rain_days_monthly.month.unique())
print(number_of_rain_days_monthly.no_of_rainy_days.unique())

# %%
# the month column is a string/object. convert it to date-time format
number_of_rain_days_monthly.month = pd.to_datetime(number_of_rain_days_monthly.month)

# %%
# confirm that the data type has been fixed
number_of_rain_days_monthly.dtypes
# Out:
# month               datetime64[ns]
# no_of_rainy_days             int64
# dtype: object

# %%
# read the rainfall-monthly-total-2023 csv file, and make it into a dataframe rain_monthly_total
rain_monthly_total = pd.read_csv('../data/rainfall-monthly-total-2023.csv')

# %%
# display the first 5 rows of dataframe
rain_monthly_total.head()
# Out:
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2

# %%
# check the data types of the dataframe
rain_monthly_total.dtypes
# Out:
# month              object
# total_rainfall    float64
# dtype: object

# %%
# check for any null values
print(rain_monthly_total.isnull().sum())
print(rain_monthly_total.month.unique())
print(rain_monthly_total.total_rainfall.unique())

# %%
# the month column is a string/object. convert it to date-time format
rain_monthly_total.month = pd.to_datetime(rain_monthly_total.month)

# %%
# confirm that the data type has been fixed
rain_monthly_total.dtypes
# Out:
# month             datetime64[ns]
# total_rainfall           float64
# dtype: object

# %%
# do a left join based on month for both the number_of_rain_days_monthly and rain_monthly_total dataframes
df_merged_rainfall = pd.merge(number_of_rain_days_monthly, rain_monthly_total, on='month', how='left')
df_merged_rainfall
# Out:
#          month  no_of_rainy_days  total_rainfall
# 0   1982-01-01                10           107.1
# 1   1982-02-01                 5            27.8
# 2   1982-03-01                11           160.8
# 3   1982-04-01                14           157.0
# 4   1982-05-01                10           102.2
# ..         ...               ...             ...
# 491 2022-12-01                19           215.4
# 492 2023-01-01                22           302.6
# 493 2023-02-01                13           324.4
# 494 2023-03-01                12           243.4
# 495 2023-04-01                19           222.8
#
# [496 rows x 3 columns]

# %%
# split the 'month' column into 2 seperate columns: year and month
df_merged_rainfall['year'] = df_merged_rainfall['month'].dt.year
df_merged_rainfall['month'] = df_merged_rainfall['month'].dt.month

# %%
# reorder the columns in the dataframe
df_merged_rainfall = df_merged_rainfall[['year','month','no_of_rainy_days','total_rainfall']]
df_merged_rainfall
# Out:
#      year  month  no_of_rainy_days  total_rainfall
# 0    1982      1                10           107.1
# 1    1982      2                 5            27.8
# 2    1982      3                11           160.8
# 3    1982      4                14           157.0
# 4    1982      5                10           102.2
# ..    ...    ...               ...             ...
# 491  2022     12                19           215.4
# 492  2023      1                22           302.6
# 493  2023      2                13           324.4
# 494  2023      3                12           243.4
# 495  2023      4                19           222.8
#
# [496 rows x 4 columns]

# %%
sd_all = {col:calculate_std(value) for col,value in df_merged_rainfall.items()}
del sd_all['year']
del sd_all['month']
sd_all
# Out:
# {'no_of_rainy_days': 4.988721345271753, 'total_rainfall': 113.56159155300686}

# %%
# rename the no_of_rainy_days column to no_of_rainy_days_in_month
# rename the total_rainfall column to total_rainfall_in_month
df_merged_rainfall = df_merged_rainfall.rename(columns={'no_of_rainy_days': 'no_of_rainy_days_in_month', 'total_rainfall':'total_rainfall_in_month'})

# define a function to convert numerical month to alphabetical month
def convert_month_to_alphabets(month):
    alphabet_months = ['January', 'February','March','April','May','June', 'July','August','September','October','November','December']
    month = alphabet_months[month-1]
    return month
# map the month column to convert to alphabetical month with the function above    
df_merged_rainfall['month'] = df_merged_rainfall['month'].map(convert_month_to_alphabets)

# %%
# check the dataframe again
df_merged_rainfall.head(12)
# Out:
#     year      month  no_of_rainy_days_in_month  total_rainfall_in_month
# 0   1982    January                         10                    107.1
# 1   1982   February                          5                     27.8
# 2   1982      March                         11                    160.8
# 3   1982      April                         14                    157.0
# 4   1982        May                         10                    102.2
# 5   1982       June                          8                     59.5
# 6   1982       July                          8                     76.3
# 7   1982     August                         11                    169.5
# 8   1982  September                          9                     54.1
# 9   1982    October                         10                     39.3
# 10  1982   November                         13                    134.0
# 11  1982   December                         21                    494.1

# %%
# save the merged dataframe into 1 csv file
df_merged_rainfall.to_csv('../data/merged_rainfall-monthly-number-of-rain-days_rainfall-monthly-total-2023.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |no_of_rainy_days_in_month|int|monthly-number-of-rain-days-2023|Monthly number of rain days from 1982 to 2023. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more|
# |total_rainfall_in_month|float|rainfall-monthly-total-2023|Monthly total rain recorded in mm from 1982 to 2023|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# show summary statistics
df_merged_rainfall.describe()
# Out:
#               year  no_of_rainy_days_in_month  total_rainfall_in_month
# count   496.000000                 496.000000               496.000000
# mean   2002.169355                  14.141129               178.383669
# std      11.945142                   4.993758               113.676242
# min    1982.000000                   1.000000                 0.200000
# 25%    1992.000000                  11.000000                95.400000
# 50%    2002.000000                  14.000000               160.550000
# 75%    2012.250000                  18.000000               239.850000
# max    2023.000000                  27.000000               765.900000

# %%
# Investigate trends in the data.


# Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
# create a data frame containing only 1990 data
df_merged_rainfall_1990 = df_merged_rainfall[df_merged_rainfall['year']==1990]
# print(df_merged_rainfall_1990)
# sort the 1990 data by total_rainfall_in_month in descending order, then locate the first row item of total_rainfall_in_month
# sort the 1990 data by ascending order, then locate the first row item of total_rainfall_in_month
# create an f-string to report the finding
print(f"In 1990, {df_merged_rainfall_1990.sort_values('total_rainfall_in_month', ascending=False).iloc[0,1]} had the highest rainfall at {df_merged_rainfall_1990.sort_values('total_rainfall_in_month', ascending=False).iloc[0,3]}mm, while {df_merged_rainfall_1990.sort_values('total_rainfall_in_month').iloc[0,1]} had the lowest rainfall at {df_merged_rainfall_1990.sort_values('total_rainfall_in_month').iloc[0,3]}mm.")

# create a data frame containing only 2000 data
df_merged_rainfall_2000 = df_merged_rainfall[df_merged_rainfall['year']==2000]
# print(df_merged_rainfall_2000)
# sort the 2000 data by total_rainfall_in_month in descending order, then locate the first row item of total_rainfall_in_month
# sort the 2000 data by ascending order, then locate the first row item of total_rainfall_in_month
# create an f-string to report the finding
print(f"In 2000, {df_merged_rainfall_2000.sort_values('total_rainfall_in_month', ascending=False).iloc[0,1]} had the highest rainfall at {df_merged_rainfall_2000.sort_values('total_rainfall_in_month', ascending=False).iloc[0,3]}mm, while {df_merged_rainfall_2000.sort_values('total_rainfall_in_month').iloc[0,1]} had the lowest rainfall at {df_merged_rainfall_2000.sort_values('total_rainfall_in_month').iloc[0,3]}mm.")

# create a data frame containing only 2010 data
df_merged_rainfall_2010 = df_merged_rainfall[df_merged_rainfall['year']==2010]
# print(df_merged_rainfall_2010)
# sort the 2010 data by total_rainfall_in_month in descending order, then locate the first row item of total_rainfall_in_month
# sort the 2010 data by ascending order, then locate the first row item of total_rainfall_in_month
# create an f-string to report the finding
print(f"In 2010, {df_merged_rainfall_2010.sort_values('total_rainfall_in_month', ascending=False).iloc[0,1]} had the highest rainfall at {df_merged_rainfall_2010.sort_values('total_rainfall_in_month', ascending=False).iloc[0,3]}mm, while {df_merged_rainfall_2010.sort_values('total_rainfall_in_month').iloc[0,1]} had the lowest rainfall at {df_merged_rainfall_2010.sort_values('total_rainfall_in_month').iloc[0,3]}mm.")

# create a data frame containing only 2020 data
df_merged_rainfall_2020 = df_merged_rainfall[df_merged_rainfall['year']==2020]
# print(df_merged_rainfall_2020)
# sort the 2020 data by total_rainfall_in_month in descending order, then locate the first row item of total_rainfall_in_month
# sort the 2020 data by ascending order, then locate the first row item of total_rainfall_in_month
# create an f-string to report the finding
print(f"In 2020, {df_merged_rainfall_2020.sort_values('total_rainfall_in_month', ascending=False).iloc[0,1]} had the highest rainfall at {df_merged_rainfall_2020.sort_values('total_rainfall_in_month', ascending=False).iloc[0,3]}mm, while {df_merged_rainfall_2020.sort_values('total_rainfall_in_month').iloc[0,1]} had the lowest rainfall at {df_merged_rainfall_2020.sort_values('total_rainfall_in_month').iloc[0,3]}mm.")
print("")

# Which year have the highest and lowest total rainfall in the date range of analysis?
# sort the main dataframe by highest and lowest total_rainfall_in_month, and then create an f-string to report the finding

print(f"{df_merged_rainfall.sort_values('total_rainfall_in_month', ascending=False).iloc[0,0]} had the highest rainfall at {df_merged_rainfall.sort_values('total_rainfall_in_month', ascending=False).iloc[0,3]}mm")
print(f"{df_merged_rainfall.sort_values('total_rainfall_in_month').iloc[0,0]} had the lowest rainfall at {df_merged_rainfall.sort_values('total_rainfall_in_month').iloc[0,3]}mm")
print("")

# Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
# repeat the same steps above for no_of_rainy_days_in_month
print(f"In 1990, {df_merged_rainfall_1990.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,1]} and {df_merged_rainfall_1990.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[1,1]} had the highest number of rainy days, while {df_merged_rainfall_1990.sort_values('no_of_rainy_days_in_month').iloc[0,1]} had the lowest number of rainy days.")
print(f"In 2000, {df_merged_rainfall_2000.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,1]} had the highest number of rainy days, while {df_merged_rainfall_2000.sort_values('no_of_rainy_days_in_month').iloc[0,1]} had the lowest number of rainy days.")
print(f"In 2010, {df_merged_rainfall_2010.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,1]} had the highest number of rainy days, while {df_merged_rainfall_2010.sort_values('no_of_rainy_days_in_month').iloc[0,1]} had the lowest number of rainy days.")
print(f"In 2020, {df_merged_rainfall_2020.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,1]} had the highest number of rainy days, while {df_merged_rainfall_2020.sort_values('no_of_rainy_days_in_month').iloc[0,1]} had the lowest number of rainy days.")
print("")

# Which year have the highest and lowest number of rainy days in the date range of analysis?
print(f"{df_merged_rainfall.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,0]} had the highest number of rainy days at {df_merged_rainfall.sort_values('no_of_rainy_days_in_month', ascending=False).iloc[0,2]}")
print(f"{df_merged_rainfall.sort_values('no_of_rainy_days_in_month').iloc[0,0]} had the lowest number of rainy days at {df_merged_rainfall.sort_values('no_of_rainy_days_in_month').iloc[0,2]}")
# Out:
# In 1990, September had the highest rainfall at 204.5mm, while February had the lowest rainfall at 24.1mm.
# In 2000, November had the highest rainfall at 385.7mm, while September had the lowest rainfall at 81.1mm.
# In 2010, July had the highest rainfall at 298.5mm, while February had the lowest rainfall at 6.3mm.
# In 2020, May had the highest rainfall at 255.6mm, while February had the lowest rainfall at 65.0mm.
#
# 2006 had the highest rainfall at 765.9mm
# 2014 had the lowest rainfall at 0.2mm
#
# In 1990, September and November had the highest number of rainy days, while March had the lowest number of rainy days.
# In 2000, November had the highest number of rainy days, while May had the lowest number of rainy days.
# In 2010, November had the highest number of rainy days, while February had the lowest number of rainy days.
# In 2020, July had the highest number of rainy days, while January had the lowest number of rainy days.
#
# 2022 had the highest number of rainy days at 27
# ...

# %%
# Are there any outliers months in the dataset?

# calculate 3 standard deviations for each column
std3_no_of_rainy_days_in_month = 3 * sd_all['no_of_rainy_days']
std3_total_rainfall_in_month = 3 * sd_all['total_rainfall']

# for no_of_rainy_days_in_month, calculate the value of mean + 3 standard deviations and mean - 3 standard deviations
outlier_top_value_rainy_day = df_merged_rainfall['no_of_rainy_days_in_month'].mean() + std3_no_of_rainy_days_in_month
outlier_bottom_value_rainy_day = df_merged_rainfall['no_of_rainy_days_in_month'].mean() - std3_no_of_rainy_days_in_month


# for total_rainfall_in_month, calculate the value of mean + 3 standard deviations and mean - 3 standard deviations
outlier_top_value_total_rainfall = df_merged_rainfall['total_rainfall_in_month'].mean() + std3_total_rainfall_in_month
outlier_bottom_value_total_rainfall = df_merged_rainfall['total_rainfall_in_month'].mean() - std3_total_rainfall_in_month


# create a new dataframe for number of rainy days in month, showing the outliers by excluding data that falls within 3 std from mean
df_outliers_no_of_rainy_days_in_month = df_merged_rainfall[~df_merged_rainfall['no_of_rainy_days_in_month'].between(outlier_bottom_value_rainy_day,outlier_top_value_rainy_day)]
print(df_outliers_no_of_rainy_days_in_month)
print('There are no outliers for number of rainy days in a month.\n')

# create a new dataframe for total rainfall in month, showing the outliers by excluding data that falls within 3 std from mean
df_outliers_total_rainfall_in_month = df_merged_rainfall[~df_merged_rainfall['total_rainfall_in_month'].between(outlier_bottom_value_total_rainfall,outlier_top_value_total_rainfall)]
print(f'Outliers for total rainfall in a month are shown below:\n{df_outliers_total_rainfall_in_month}')
# Out:
# Empty DataFrame
# Columns: [year, month, no_of_rainy_days_in_month, total_rainfall_in_month]
# Index: []
# There are no outliers for number of rainy days in a month.
#
# Outliers for total rainfall in a month are shown below:
#      year     month  no_of_rainy_days_in_month  total_rainfall_in_month
# 60   1987   January                         16                    568.6
# 239  2001  December                         20                    609.0
# 264  2004   January                         13                    600.9
# 299  2006  December                         22                    765.9
# 468  2021   January                         17                    692.8

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %%
# Code .corr btw rainfall days and total rainfall
df_merged_rainfall['total_rainfall_in_month'].corr(df_merged_rainfall['no_of_rainy_days_in_month'])
# Out:
# 0.6826611300679717

# %%
# create a heatmap of correlation coefficients between df columns total_rainfall_in_month and no_of_rainy_days_in_month
# annot=True means to show the column names on both axes of the heatmap

df_merged_rainfall_without_year_month = df_merged_rainfall.loc[:,['no_of_rainy_days_in_month','total_rainfall_in_month']]

plt.figure(figsize=(5,5))
sns.heatmap(df_merged_rainfall_without_year_month.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Interpretation of heatmap and correlation**:
#
# There is correlation coefficient of about 0.68, which suggests a slight positive correlation between the total rainfall and the number of rainy days in a month. This is expected since more rainy days will be likely to increase the amount of total rainfall.

# %%
df_merged_rainfall.plot(kind='scatter', x='no_of_rainy_days_in_month', y='total_rainfall_in_month')
plt.title('Scatterplot between no_of_rainy_days_in_month and total_rainfall_in_month')
# Out:
# Text(0.5, 1.0, 'Scatterplot between no_of_rainy_days_in_month and total_rainfall_in_month')

# %% [markdown]
# **Interpretation of Scatterplot between no_of_rainy_days_in_month and total_rainfall_in_month**:
#
# The scatterplot furthur shows the slight positive correlation between the total rainfall and the number of rainy days in a month. The scatterplot also shows the presence of outliers that are present in the data.

# %%
# plot a histogram for monthly rainfall

# Create the plot
fig, ax = plt.subplots()
ax.hist(df_merged_rainfall['total_rainfall_in_month'], bins=10)

# Calculate the mean
mean = np.mean(df_merged_rainfall['total_rainfall_in_month'])

# Add the vertical line representing the mean
ax.axvline(mean, color='r', linestyle='--', label='Mean')

# Add legend and labels
ax.legend()
ax.set_xlabel('Monthly Rainfall (mm)')
ax.set_ylabel('Frequency')
ax.set_title('Histogram of Monthly Rainfall')

# Show the plot
plt.show()

# %% [markdown]
# **Interpretation of Histogram of Monthly Rainfall**:
#
# From the histogram, the monthly rainfall appears to follow a normal distribution centered around the mean of about 178mm. There also appears to be a few outliers on the right side of the historgram.

# %%
df_merged_rainfall['total_rainfall_in_month'].plot(kind='box')

plt.ylabel('total_rainfall_in_month in mm')
plt.title('Boxplot for Monthly Total Rainfall ')
# Out:
# Text(0.5, 1.0, 'Boxplot for Monthly Total Rainfall ')

# %% [markdown]
# **Interpretation of Boxplot for Monthly Total Rainfall**:
#
# The boxplot furthur shows the outliers in the data for total_rainfall_in_month

# %%
# plot a histogram for number of rainy days

# Create the plot
fig, ax = plt.subplots()
ax.hist(df_merged_rainfall['no_of_rainy_days_in_month'], bins=10)

# Calculate the mean
mean = np.mean(df_merged_rainfall['no_of_rainy_days_in_month'])

# Add the vertical line representing the mean
ax.axvline(mean, color='r', linestyle='--', label='Mean')

# Add legend and labels
ax.legend()
ax.set_xlabel('Number of rainy days')
ax.set_ylabel('Frequency')
ax.set_title('Histogram of Number of Rainy Days in a Month')

# Show the plot
plt.show()

# %% [markdown]
# **Interpretation of Histogram of Number of Rainy Days in a Month**:
#
# From the histogram, the monthly number of rainy days appears to follow a normal distribution as well, centered around the mean of 14.

# %%
df_merged_rainfall['no_of_rainy_days_in_month'].plot(kind='box')

plt.ylabel('no_of_rainy_days_in_month')
plt.title('Boxplot for Monthly Number of Rainy Days ')
# Out:
# Text(0.5, 1.0, 'Boxplot for Monthly Number of Rainy Days ')

# %% [markdown]
# **Interpretation of Boxplot for Monthly Number of Rainy Days**:
#
# The boxplot shows the absence of any outliers in the data for no_of_rainy_days_in_month

# %%
# Group data by month before beginning to plot charts by month
grouped_data = df_merged_rainfall.groupby(df_merged_rainfall['month']).mean()
grouped_data.reset_index(inplace=True)
grouped_data
# Out:
#         month    year  no_of_rainy_days_in_month  total_rainfall_in_month
# 0       April  2002.5                  14.547619               160.011905
# 1      August  2002.0                  13.902439               149.424390
# 2    December  2002.0                  18.658537               308.719512
# 3    February  2002.5                   8.404762               109.169048
# 4     January  2002.5                  13.571429               235.921429
# 5        July  2002.0                  13.512195               147.387805
# 6        June  2002.0                  13.195122               135.180488
# 7       March  2002.5                  12.476190               162.869048
# 8         May  2002.0                  13.926829               166.221951
# 9    November  2002.0                  19.195122               257.575610
# 10    October  2002.0                  15.243902               162.587805
# 11  September  2002.0                  13.243902               146.646341

# %%
# to plot the average total rainfall in each month based on data from 1982 to 2023 (2023 up till April)

grouped_data['Month'] = pd.Categorical(grouped_data['month'], categories=['January', 'February', 'March', 'April', 'May', 'June','July','August', 'September','October', 'November', 'December'], ordered=True)


# Sort the DataFrame by the categorical order
grouped_data = grouped_data.sort_values('Month')

# Plot the data
plt.plot(grouped_data['Month'], grouped_data['total_rainfall_in_month'])
plt.xlabel('Month')
plt.ylabel('total_rainfall_in_month in mm')
plt.title('Average Monthly Total Rainfall by Month of Year')
plt.xticks(rotation=45)

# Set custom labels for x-axis
custom_labels = ['Jan', 'Feb', 'Mar', 'Apr','May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(grouped_data['Month'], custom_labels)

# Calculate the average
average = np.mean(grouped_data['total_rainfall_in_month'])

# Add a horizontal line at the average value
plt.axhline(y=average, color='red', linestyle='--',label='Mean')

plt.show()

# %% [markdown]
# **Interpretation of the line plot**:
#
# The line plot shows that February has the lowest average monthly total rainfall as compared to other months, whereas December has the highest average monthly total rainfall as compared to other months. The average monthly total rainfall for each month between October, November, December and January are higher than the average (denoted as a red dotted line in the plot) across the 12 months.
#
# This observation is generally in line with the timeframe of the Northeast Monsoon occuring from December to early March, where we are likely to see heavy rainfall in first half of the Northeast Monsoon season, usually from December to early January, followed by relatively drier in the later part of the season, usually from late January to early March. The intermonsoon period see thunderstorms generally, though not expected to be as much as that of the early Northeast Monsoon season.

# %%
# to plot the average number of rainy days in each month based on data from 1982 to 2023 (2023 up till April)

grouped_data['Month'] = pd.Categorical(grouped_data['month'], categories=['January', 'February', 'March', 'April', 'May', 'June','July','August', 'September','October', 'November', 'December'], ordered=True)


# Sort the DataFrame by the categorical order
grouped_data = grouped_data.sort_values('Month')

# Plot the data
plt.plot(grouped_data['Month'], grouped_data['no_of_rainy_days_in_month'])
plt.xlabel('Month')
plt.ylabel('no_of_rainy_days_in_month')
plt.title('Average Number of Rainy Days by Month of Year')
plt.xticks(rotation=45)

# Set custom labels for x-axis
custom_labels = ['Jan', 'Feb', 'Mar', 'Apr','May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(grouped_data['Month'], custom_labels)

# Calculate the average
average = np.mean(grouped_data['no_of_rainy_days_in_month'])

# Add a horizontal line at the average value
plt.axhline(y=average, color='red', linestyle='--',label='Mean')

plt.show()

# %% [markdown]
# **Interpretation of the line plot**:
#
# The line plot shows that the months from October to December have higher than average number of rainy days in the month, while February has the lowest. This is also in line with the heavy rainfall in first half of the Northeast Monsoon season as explained earlier above, and also given the slight positive correlation between the total rainfall and the number of rainy days in a month described in the heatmap earlier.

# %%
grouped_data_year = df_merged_rainfall.groupby(df_merged_rainfall['year']).mean()
grouped_data_year.reset_index(inplace=True)
grouped_data_year
# Out:
# C:\Users\Jackson\AppData\Local\Temp\ipykernel_8596\3456277910.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data_year = df_merged_rainfall.groupby(df_merged_rainfall['year']).mean()
#     year  no_of_rainy_days_in_month  total_rainfall_in_month
# 0   1982                  10.833333               131.808333
# 1   1983                  12.083333               166.141667
# 2   1984                  15.916667               223.891667
# 3   1985                  15.083333               123.658333
# 4   1986                  14.500000               211.341667
# 5   1987                  12.583333               175.233333
# 6   1988                  14.416667               216.550000
# 7   1989                  14.416667               205.266667
# ...

# %%
# to plot the average monthly total rainfall for each year from 1982 to 2023 (2023 up till April)




# Plot the data
plt.plot(grouped_data_year['year'], grouped_data_year['total_rainfall_in_month'])
plt.xlabel('Year')
plt.ylabel('total_rainfall_in_month in mm')
plt.title('Average Monthly Total Rainfall by Year')
plt.xticks(rotation=45)



# Calculate the average
average = np.mean(grouped_data_year['total_rainfall_in_month'])

# Add a horizontal line at the average value
plt.axhline(y=average, color='red', linestyle='--', label='Mean')

plt.show()

# %% [markdown]
# **Interpretation of the line plot**:
#
# The line plot shows the average monthly total rainfall increases and decreases in cycles throughout the years. This is in line with the difference in rainfall between the monsoon periods that have higher rainfall and the intermonsoon periods that have relatively lower rainfall.
#
# The particularly low dip in the line plot between 1990 and 2000 can be explained by the El Nino weather phenomenon reported in 1997 where there was extreme low rainfall.
#
# As we move furthur over the years to the present, there appears to be increased volatility of the increase and decrease of rainfall between the cycles.
# As we go from 2000 to the present, the peaks within each high and low rainfall cycles are getting higher, while the lowest points of each cycle are getting lower throughout the years.
# This supports the findings from studies that there will likely be more extreme weather variations with climate change, especially between the drier El Nino and the wetter La Nina events.

# %%
# to plot the average monthly number of rainy days for each year from 1982 to 2023 (2023 up till April)


# Plot the data
plt.plot(grouped_data_year['year'], grouped_data_year['no_of_rainy_days_in_month'])
plt.xlabel('Year')
plt.ylabel('no_of_rainy_days_in_month')
plt.title('Average Number of Rainy Days by Year')
plt.xticks(rotation=45)


# Calculate the average
average = np.mean(grouped_data_year['no_of_rainy_days_in_month'])

# Add a horizontal line at the average value
plt.axhline(y=average, color='red', linestyle='--', label='Mean')

plt.show()

# %% [markdown]
# **Interpretation of the line plot**:
#
# The line plot for average number of rainy days in a month by year sees similarities as the line plot for average monthly total rainfall. There is a similar dip for the 1997 El Nino dry period. The increase in volatility mentioned earlier is also seen here for the number of rainy days in a month.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# The key takeaways from the exploration of the data are as follows:
#
# 1. There is a slight positive correlation between the total rainfall and the number of rainy days in a month
# 2. Both the total rainfall and the number of rainy days in a month generally follow a normal distribution
# 3. There appears to be increased volatility of the increase and decrease of rainfall between the high and low rainfall cycles through the years, which supports the observation of extreme weather and rainfall variations
#
#
# With the increasing extreme weather and rainfall variations expected and observed, there is an urgent need to review and update Singapore's urban development plans, especially flood adaptation measures. Singapore's urban landscape, characterized by rapid urbanization and limited land resources, has undergone significant development over the decades, often prioritizing economic growth and urban expansion. However, these traditional urban development practices may not adequately account for the changing climate and the increased risk of flooding. The socio-economic impact of flooding events can be far-reaching, leading to economic losses, displacement of residents, and long-term damage to the city-state's reputation as a global hub.
# As such, after gaining insights on rainfall from this project, the next steps I recommend include:
#
# 1. Analyse rainfall variations between each district of Singapore to prioritise efforts on districts that have higher rainfall and more prone to flooding, in the case of limited budget and resources
# 2. Build accurate models to predict the future amount of rainfall and length of extreme wet and dry periods, taking into account the extreme weather variations
# 3. Review existing drainage system and identify gaps in future-proofing flood and stormwater management measures
# 4. Review existing urban plans, especially for older estates, to determine and plug gaps in flood preparedness, as well as on-site mitigation measures such as detention tanks, green roofs, rain gardens or retention ponds

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
